# %% [markdown]
# <a href="https://colab.research.google.com/github/syeong1218/RL/blob/master/A2C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:

    # %tensorflow_version 2.x  # %tensorflow_version only exists in Colab

except Exception:

    pass
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # %tensorflow_version only exists in Colab`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.

# %%
import numpy as np

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Lambda

import tensorflow as tf

class Actor(object):
    def __init__(self, state_dim, action_dim, action_bound, learning_rate):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.action_bound = action_bound
        self.learning_rate = learning_rate

        self.std_bound = [1e-2, 1.0] # std bound

        self.model = self.build_network()

        self.actor_optimizer = tf.keras.optimizers.Adam(learning_rate)


    ## actor network
    def build_network(self):
        state_input = Input((self.state_dim,))
        h1 = Dense(64, activation='relu')(state_input)
        h2 = Dense(32, activation='relu')(h1)
        h3 = Dense(16, activation='relu')(h2)
        out_mu = Dense(self.action_dim, activation='tanh')(h3)
        std_output = Dense(self.action_dim, activation='softplus')(h3)

        # Scale output to [-action_bound, action_bound]
        mu_output = Lambda(lambda x: x*self.action_bound)(out_mu)
        model = Model(state_input, [mu_output, std_output])
        model.summary()
        return model

    ## log policy pdf
    def log_pdf(self, mu, std, action):
        std = tf.clip_by_value(std, self.std_bound[0], self.std_bound[1])
        var = std**2
        log_policy_pdf = -0.5 * (action - mu) ** 2 / var - 0.5 * tf.math.log(var * 2 * np.pi)
        return tf.reduce_sum(log_policy_pdf, 1, keepdims=True)


    ## actor policy
    def get_action(self, state):
        # type of action in env is numpy array
        # np.reshape(state, [1, self.state_dim]) : shape (state_dim,) -> shape (1, state_dim)
        # why [0]?  shape (1, action_dim) -> (action_dim,)
        mu_a, std_a = self.model.predict(np.reshape(state, [1, self.state_dim]))
        mu_a = mu_a[0]
        std_a = std_a[0]
        std_a = np.clip(std_a, self.std_bound[0], self.std_bound[1])
        action = np.random.normal(mu_a, std_a, size=self.action_dim)
        return action

    def train(self, states, actions, advantages):
        with tf.GradientTape() as tape:
            # policy pdf
            mu_a, std_a = self.model(states)
            log_policy_pdf = self.log_pdf(mu_a, std_a, actions)

            # loss functions and its gradient
            loss_policy = log_policy_pdf * advantages
            loss = tf.reduce_sum(-loss_policy)
        dj_dtheta = tape.gradient(loss, self.model.trainable_variables)
        grads = zip(dj_dtheta, self.model.trainable_variables)
        self.actor_optimizer.apply_gradients(grads)

    ## actor prediction
    def predict(self, state):
        mu_a, _= self.model.predict(np.reshape(state, [1, self.state_dim]))
        return mu_a[0]

    ## save actor weights
    def save_weights(self, path):
        self.model.save_weights(path)


    ## load actor wieghts
    def load_weights(self, path):
        self.model.load_weights(path + 'pendulum_actor.h5')

# %%
# A2C Agent for training and evaluation

import numpy as np
import tensorflow as tf
import keras.backend as K
import matplotlib.pyplot as plt


class A2Cagent(object):

    def __init__(self, env):

        # hyperparameters
        self.GAMMA = 0.95
        self.BATCH_SIZE = 32
        self.ACTOR_LEARNING_RATE = 0.0001
        self.CRITIC_LEARNING_RATE = 0.001

        self.env = env
        # get state dimension
        self.state_dim = env.observation_space.shape[0]
        # get action dimension
        self.action_dim = env.action_space.shape[0]
        # get action bound
        self.action_bound = env.action_space.high[0]

        # create actor and critic networks
        self.actor = Actor(self.state_dim, self.action_dim, self.action_bound, self.ACTOR_LEARNING_RATE)
        self.critic = Critic(self.state_dim, self.action_dim, self.CRITIC_LEARNING_RATE)

        # save the results
        self.save_epi_reward = []


    ## computing Advantages and targets: y_k = r_k + gamma*V(s_k+1), A(s_k, a_k)= y_k - V(s_k)
    def advantage_td_target(self, reward, v_value, next_v_value, done):
        if done:
                y_k = reward
                advantage = y_k - v_value
        else:
                y_k = reward + self.GAMMA * next_v_value
                advantage = y_k - v_value
        return advantage, y_k


    ## convert (list of np.array) to np.array
    def unpack_batch(self, batch):
        unpack = batch[0]
        for idx in range(len(batch)-1):
            unpack = np.append(unpack, batch[idx+1], axis=0)

        return unpack


    ## train the agent
    def train(self, max_episode_num):

        for ep in range(int(max_episode_num)):

            # initialize batch
            batch_state, batch_action, batch_td_target, batch_advantage = [], [], [], []
            # reset episode
            time, episode_reward, done = 0, 0, False
            # reset the environment and observe the first state
            state = self.env.reset() # shape of state from gym (3,)

            while not done:

                # visualize the environment
                #self.env.render()
                # pick an action (shape of gym action = (action_dim,) )
                action = self.actor.get_action(state)
                # clip continuous action to be within action_bound
                action = np.clip(action, -self.action_bound, self.action_bound)
                # observe reward, new_state, shape of output of gym (state_dim,)
                next_state, reward, done, _ = self.env.step(action)
                # change shape (state_dim,) -> (1, state_dim), same to action, next_state
                state = np.reshape(state, [1, self.state_dim])
                next_state = np.reshape(next_state, [1, self.state_dim])
                action = np.reshape(action, [1, self.action_dim])
                reward = np.reshape(reward, [1, 1])
                # compute next v_value
                v_value = self.critic.model.predict(state)
                next_v_value = self.critic.model.predict(next_state)
                # compute advantage and TD target
                train_reward = (reward+8)/8  # <-- normalization
                advantage, y_i = self.advantage_td_target(train_reward, v_value, next_v_value, done)

                # append to the batch
                batch_state.append(state)
                batch_action.append(action)
                batch_td_target.append(y_i)
                batch_advantage.append(advantage)

                # continue until batch becomes full
                if len(batch_state) < self.BATCH_SIZE:
                    # update current state
                    state = next_state[0]
                    episode_reward += reward[0]
                    time += 1
                    continue

                # if batch is full, start to train networks on batch
                # extract batched states, actions, td_targets, advantages
                states = self.unpack_batch(batch_state)
                actions = self.unpack_batch(batch_action)
                td_targets = self.unpack_batch(batch_td_target)
                advantages = self.unpack_batch(batch_advantage)
                # clear the batch
                batch_state, batch_action, batch_td_target, batch_advantage = [], [], [], []
                # train critic
                self.critic.train_on_batch(states, td_targets)
                # train actor
                self.actor.train(states, actions, advantages)

                # update current state
                state = next_state[0]
                episode_reward += reward[0]
                time += 1


            ## display rewards every episode
            print('Episode: ', ep+1, 'Time: ', time, 'Reward: ', episode_reward)

            self.save_epi_reward.append(episode_reward)


            ## save weights every episode
            if ep % 10 == 0:
                self.actor.save_weights("./save_weights/pendulum_actor.h5")
                self.critic.save_weights("./save_weights/pendulum_critic.h5")

        np.savetxt('./save_weights/pendulum_epi_reward.txt', self.save_epi_reward)
        print(self.save_epi_reward)


    ## save them to file if done
    def plot_result(self):
        plt.plot(self.save_epi_reward)
        plt.show()

# %%
# A2C Critic

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam

class Critic(object):
    """
        Critic Network for A2C: V function approximator
    """
    def __init__(self, state_dim, action_dim, learning_rate):

        self.state_dim = state_dim
        self.action_dim = action_dim
        self.learning_rate = learning_rate

        # create and compile critic network
        self.model, self.states = self.build_network()

        self.model.compile(optimizer=Adam(self.learning_rate), loss='mse')

    ## critic network
    def build_network(self):
        state_input = Input((self.state_dim,))
        h1 = Dense(64, activation='relu')(state_input)
        h2 = Dense(32, activation='relu')(h1)
        h3 = Dense(16, activation='relu')(h2)
        v_output = Dense(1, activation='linear')(h3)
        model = Model(state_input, v_output)
        model.summary()
        return model, state_input


    ## single gradient update on a single batch data
    def train_on_batch(self, states, td_targets):
        return self.model.train_on_batch(states, td_targets)


    ## save critic weights
    def save_weights(self, path):
        self.model.save_weights(path)


    ## load critic wieghts
    def load_weights(self, path):
        self.model.load_weights(path + 'pendulum_critic.h5')

# %%
# A2C main

import gym

def main():

    max_episode_num = 1000
    env_name = 'Pendulum-v0'
    env = gym.make(env_name)
    agent = A2Cagent(env)

    agent.train(max_episode_num)

    agent.plot_result()



if __name__=="__main__":
    main()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 3)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           256         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           2080        dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           528         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            17          dense_2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1)            0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            17          dense_2[0][0]
# ==================================================================================================
# Total params: 2,898
# Trainable params: 2,898
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 2,881
# Trainable params: 2,881
# Non-trainable params: 0
# _________________________________________________________________
# Episode:  1 Time:  200 Reward:  [-1648.13779536]
# Episode:  2 Time:  200 Reward:  [-1519.48939481]
# Episode:  3 Time:  200 Reward:  [-1589.48216227]
# Episode:  4 Time:  200 Reward:  [-1549.03520038]
# Episode:  5 Time:  200 Reward:  [-1873.91475581]
# Episode:  6 Time:  200 Reward:  [-1617.34467058]
# Episode:  7 Time:  200 Reward:  [-1596.34314807]
# Episode:  8 Time:  200 Reward:  [-1365.54698268]
# Episode:  9 Time:  200 Reward:  [-1483.80796709]
# Episode:  10 Time:  200 Reward:  [-1721.05981758]
# Episode:  11 Time:  200 Reward:  [-1585.06375174]
# Episode:  12 Time:  200 Reward:  [-1671.26561792]
# Episode:  13 Time:  200 Reward:  [-1863.13341938]
# Episode:  14 Time:  200 Reward:  [-1542.68948629]
# Episode:  15 Time:  200 Reward:  [-1472.26928957]
# Episode:  16 Time:  200 Reward:  [-1807.10864818]
# Episode:  17 Time:  200 Reward:  [-1842.49134359]
# Episode:  18 Time:  200 Reward:  [-1498.26253422]
# Episode:  19 Time:  200 Reward:  [-1762.76040365]
# Episode:  20 Time:  200 Reward:  [-1508.32204446]
# Episode:  21 Time:  200 Reward:  [-1849.61095933]
# Episode:  22 Time:  200 Reward:  [-1842.17844064]
# Episode:  23 Time:  200 Reward:  [-1700.42240537]
# Episode:  24 Time:  200 Reward:  [-1428.59307781]
# Episode:  25 Time:  200 Reward:  [-1537.9898877]
# Episode:  26 Time:  200 Reward:  [-1764.65248614]
# Episode:  27 Time:  200 Reward:  [-1483.71873047]
# Episode:  28 Time:  200 Reward:  [-1825.52094976]
# Episode:  29 Time:  200 Reward:  [-1614.84856444]
# Episode:  30 Time:  200 Reward:  [-1426.59377188]
# Episode:  31 Time:  200 Reward:  [-1484.92023246]
# Episode:  32 Time:  200 Reward:  [-1032.35989055]
# Episode:  33 Time:  200 Reward:  [-1076.70999739]
# Episode:  34 Time:  200 Reward:  [-1726.23225539]
# Episode:  35 Time:  200 Reward:  [-1857.16781786]
# Episode:  36 Time:  200 Reward:  [-1479.93567527]
# Episode:  37 Time:  200 Reward:  [-1718.82555134]
# Episode:  38 Time:  200 Reward:  [-1809.74038807]
# Episode:  39 Time:  200 Reward:  [-1418.75008205]
# Episode:  40 Time:  200 Reward:  [-1489.95542544]
# Episode:  41 Time:  200 Reward:  [-1212.33117843]
# Episode:  42 Time:  200 Reward:  [-1647.8874401]
# Episode:  43 Time:  200 Reward:  [-1587.91499497]
# Episode:  44 Time:  200 Reward:  [-1576.33451143]
# Episode:  45 Time:  200 Reward:  [-1203.78280008]
# Episode:  46 Time:  200 Reward:  [-1623.51719937]
# Episode:  47 Time:  200 Reward:  [-1435.10629884]
# Episode:  48 Time:  200 Reward:  [-1809.05154856]
# Episode:  49 Time:  200 Reward:  [-1740.3518218]
# Episode:  50 Time:  200 Reward:  [-1871.78464131]
# Episode:  51 Time:  200 Reward:  [-1569.66111346]
# Episode:  52 Time:  200 Reward:  [-1414.18223825]
# Episode:  53 Time:  200 Reward:  [-1863.44987615]
# Episode:  54 Time:  200 Reward:  [-1666.88176154]
# Episode:  55 Time:  200 Reward:  [-1595.63501996]
# Episode:  56 Time:  200 Reward:  [-1482.41171588]
# Episode:  57 Time:  200 Reward:  [-1504.77476315]
# Episode:  58 Time:  200 Reward:  [-1325.15395475]
# Episode:  59 Time:  200 Reward:  [-1643.7919439]
# Episode:  60 Time:  200 Reward:  [-1637.85676953]
# Episode:  61 Time:  200 Reward:  [-965.73359514]
# Episode:  62 Time:  200 Reward:  [-1570.43962595]
# Episode:  63 Time:  200 Reward:  [-1316.88713202]
# Episode:  64 Time:  200 Reward:  [-1363.59895958]
# Episode:  65 Time:  200 Reward:  [-1476.21023707]
# Episode:  66 Time:  200 Reward:  [-1240.98962729]
# Episode:  67 Time:  200 Reward:  [-1228.63675927]
# Episode:  68 Time:  200 Reward:  [-1333.61520932]
# Episode:  69 Time:  200 Reward:  [-1254.32902403]
# Episode:  70 Time:  200 Reward:  [-1277.06383105]
# Episode:  71 Time:  200 Reward:  [-1400.26093962]
# Episode:  72 Time:  200 Reward:  [-1171.29777725]
# Episode:  73 Time:  200 Reward:  [-1503.3681323]
# Episode:  74 Time:  200 Reward:  [-1225.58157314]
# Episode:  75 Time:  200 Reward:  [-1186.88091782]
# Episode:  76 Time:  200 Reward:  [-1119.66183537]
# Episode:  77 Time:  200 Reward:  [-1295.89843708]
# Episode:  78 Time:  200 Reward:  [-1297.30141647]
# Episode:  79 Time:  200 Reward:  [-1474.00605023]
# Episode:  80 Time:  200 Reward:  [-1562.26607784]
# Episode:  81 Time:  200 Reward:  [-1170.67205583]
# Episode:  82 Time:  200 Reward:  [-1314.75716102]
# Episode:  83 Time:  200 Reward:  [-1267.37510358]
# Episode:  84 Time:  200 Reward:  [-1170.3637939]
# Episode:  85 Time:  200 Reward:  [-1107.40998094]
# Episode:  86 Time:  200 Reward:  [-1204.69505675]
# Episode:  87 Time:  200 Reward:  [-1309.33360034]
# Episode:  88 Time:  200 Reward:  [-1335.70651036]
# Episode:  89 Time:  200 Reward:  [-1376.27463675]
# Episode:  90 Time:  200 Reward:  [-1478.42337487]
# Episode:  91 Time:  200 Reward:  [-1403.19222402]
# Episode:  92 Time:  200 Reward:  [-1326.72492064]
# Episode:  93 Time:  200 Reward:  [-1249.68876664]
# Episode:  94 Time:  200 Reward:  [-1353.36410889]
# Episode:  95 Time:  200 Reward:  [-1452.45652754]
# Episode:  96 Time:  200 Reward:  [-1375.24451911]
# Episode:  97 Time:  200 Reward:  [-1450.79545514]
# Episode:  98 Time:  200 Reward:  [-1347.2645774]
# Episode:  99 Time:  200 Reward:  [-1309.57448306]
# Episode:  100 Time:  200 Reward:  [-1435.7741967]
# Episode:  101 Time:  200 Reward:  [-1317.50435691]
# Episode:  102 Time:  200 Reward:  [-1515.37441185]
# Episode:  103 Time:  200 Reward:  [-905.28415516]
# Episode:  104 Time:  200 Reward:  [-1302.95875882]
# Episode:  105 Time:  200 Reward:  [-1377.2181165]
# Episode:  106 Time:  200 Reward:  [-1298.90682132]
# Episode:  107 Time:  200 Reward:  [-1523.93142764]
# Episode:  108 Time:  200 Reward:  [-1276.94783148]
# Episode:  109 Time:  200 Reward:  [-1354.30520085]
# Episode:  110 Time:  200 Reward:  [-1146.10257175]
# Episode:  111 Time:  200 Reward:  [-1385.43729298]
# Episode:  112 Time:  200 Reward:  [-1393.35490989]
# Episode:  113 Time:  200 Reward:  [-1372.67133997]
# Episode:  114 Time:  200 Reward:  [-1276.48573081]
# Episode:  115 Time:  200 Reward:  [-1305.71004691]
# Episode:  116 Time:  200 Reward:  [-1249.49882832]
# Episode:  117 Time:  200 Reward:  [-1340.32385869]
# Episode:  118 Time:  200 Reward:  [-1382.17273393]
# Episode:  119 Time:  200 Reward:  [-1341.37923413]
# Episode:  120 Time:  200 Reward:  [-1325.72797303]
# Episode:  121 Time:  200 Reward:  [-1286.38598187]
# Episode:  122 Time:  200 Reward:  [-1349.09313379]
# Episode:  123 Time:  200 Reward:  [-1225.23980893]
# Episode:  124 Time:  200 Reward:  [-1295.67491249]
# Episode:  125 Time:  200 Reward:  [-1374.6868665]
# Episode:  126 Time:  200 Reward:  [-1285.70503222]
# Episode:  127 Time:  200 Reward:  [-1313.59855476]
# Episode:  128 Time:  200 Reward:  [-1470.34710976]
# Episode:  129 Time:  200 Reward:  [-1239.00431449]
# Episode:  130 Time:  200 Reward:  [-1443.63604563]
# Episode:  131 Time:  200 Reward:  [-1371.31242102]
# Episode:  132 Time:  200 Reward:  [-1310.51473095]
# Episode:  133 Time:  200 Reward:  [-1441.67319273]
# Episode:  134 Time:  200 Reward:  [-1315.55949888]
# Episode:  135 Time:  200 Reward:  [-1360.35905026]
# Episode:  136 Time:  200 Reward:  [-1310.42527751]
# Episode:  137 Time:  200 Reward:  [-1231.64465802]
# Episode:  138 Time:  200 Reward:  [-1456.16307755]
# Episode:  139 Time:  200 Reward:  [-1291.93983021]
# Episode:  140 Time:  200 Reward:  [-1298.30178205]
# Episode:  141 Time:  200 Reward:  [-1317.76030462]
# Episode:  142 Time:  200 Reward:  [-1340.507836]
# Episode:  143 Time:  200 Reward:  [-1324.54880009]
# Episode:  144 Time:  200 Reward:  [-1330.78913269]
# Episode:  145 Time:  200 Reward:  [-1342.00446559]
# Episode:  146 Time:  200 Reward:  [-1339.38642297]
# Episode:  147 Time:  200 Reward:  [-1412.43369792]
# Episode:  148 Time:  200 Reward:  [-1366.73211073]
# Episode:  149 Time:  200 Reward:  [-1424.27254435]
# Episode:  150 Time:  200 Reward:  [-1210.14621852]
# Episode:  151 Time:  200 Reward:  [-1370.77983579]
# Episode:  152 Time:  200 Reward:  [-1249.39373394]
# Episode:  153 Time:  200 Reward:  [-1341.41946803]
# Episode:  154 Time:  200 Reward:  [-1324.56441866]
# Episode:  155 Time:  200 Reward:  [-1348.41476166]
# Episode:  156 Time:  200 Reward:  [-1281.50465363]
# Episode:  157 Time:  200 Reward:  [-1307.26453873]
# Episode:  158 Time:  200 Reward:  [-1345.88419043]
# Episode:  159 Time:  200 Reward:  [-1314.55705176]
# Episode:  160 Time:  200 Reward:  [-1371.55162915]
# Episode:  161 Time:  200 Reward:  [-1323.33315225]
# Episode:  162 Time:  200 Reward:  [-1345.72645951]
# Episode:  163 Time:  200 Reward:  [-1322.80894853]
# Episode:  164 Time:  200 Reward:  [-1382.47154181]
# Episode:  165 Time:  200 Reward:  [-1338.78044859]
# Episode:  166 Time:  200 Reward:  [-1324.20051027]
# Episode:  167 Time:  200 Reward:  [-1313.56161866]
# Episode:  168 Time:  200 Reward:  [-1326.05658893]
# Episode:  169 Time:  200 Reward:  [-1333.88195545]
# Episode:  170 Time:  200 Reward:  [-1326.75343658]
# Episode:  171 Time:  200 Reward:  [-1381.72846718]
# Episode:  172 Time:  200 Reward:  [-1370.63579762]
# Episode:  173 Time:  200 Reward:  [-1301.98626255]
# Episode:  174 Time:  200 Reward:  [-1339.08770725]
# Episode:  175 Time:  200 Reward:  [-1292.00441312]
# Episode:  176 Time:  200 Reward:  [-1300.85899362]
# Episode:  177 Time:  200 Reward:  [-1275.50112868]
# Episode:  178 Time:  200 Reward:  [-1291.92819903]
# Episode:  179 Time:  200 Reward:  [-1273.82463566]
# Episode:  180 Time:  200 Reward:  [-1315.3366361]
# Episode:  181 Time:  200 Reward:  [-1320.59031163]
# Episode:  182 Time:  200 Reward:  [-1199.42778227]
# Episode:  183 Time:  200 Reward:  [-1187.48227277]
# Episode:  184 Time:  200 Reward:  [-1190.31223185]
# Episode:  185 Time:  200 Reward:  [-1283.95084553]
# Episode:  186 Time:  200 Reward:  [-1266.28441943]
# Episode:  187 Time:  200 Reward:  [-1310.06985116]
# Episode:  188 Time:  200 Reward:  [-1202.31450878]
# Episode:  189 Time:  200 Reward:  [-1174.77895177]
# Episode:  190 Time:  200 Reward:  [-1167.67793899]
# Episode:  191 Time:  200 Reward:  [-1397.18145251]
# Episode:  192 Time:  200 Reward:  [-1323.04193097]
# Episode:  193 Time:  200 Reward:  [-1193.70295334]
# Episode:  194 Time:  200 Reward:  [-1149.28929009]
# Episode:  195 Time:  200 Reward:  [-1376.90287638]
# Episode:  196 Time:  200 Reward:  [-1449.8261225]
# Episode:  197 Time:  200 Reward:  [-1288.27417011]
# Episode:  198 Time:  200 Reward:  [-1338.80176896]
# Episode:  199 Time:  200 Reward:  [-1445.96662453]
# Episode:  200 Time:  200 Reward:  [-1045.35442086]
# Episode:  201 Time:  200 Reward:  [-1341.26076947]
# Episode:  202 Time:  200 Reward:  [-1048.83317972]
# Episode:  203 Time:  200 Reward:  [-966.04471444]
# Episode:  204 Time:  200 Reward:  [-1315.04513733]
# Episode:  205 Time:  200 Reward:  [-1310.59783867]
# Episode:  206 Time:  200 Reward:  [-1045.72441491]
# Episode:  207 Time:  200 Reward:  [-1276.36552695]
# Episode:  208 Time:  200 Reward:  [-1245.8783843]
# Episode:  209 Time:  200 Reward:  [-1111.20592536]
# Episode:  210 Time:  200 Reward:  [-1253.75044066]
# Episode:  211 Time:  200 Reward:  [-1167.17308492]
# Episode:  212 Time:  200 Reward:  [-1315.85978439]
# Episode:  213 Time:  200 Reward:  [-1184.1607168]
# Episode:  214 Time:  200 Reward:  [-1284.90763056]
# Episode:  215 Time:  200 Reward:  [-1190.53217065]
# Episode:  216 Time:  200 Reward:  [-1318.22940273]
# Episode:  217 Time:  200 Reward:  [-1194.29856622]
# Episode:  218 Time:  200 Reward:  [-1323.63208983]
# Episode:  219 Time:  200 Reward:  [-1428.97223346]
# Episode:  220 Time:  200 Reward:  [-1166.91246087]
# Episode:  221 Time:  200 Reward:  [-1351.66230057]
# Episode:  222 Time:  200 Reward:  [-1185.71163443]
# Episode:  223 Time:  200 Reward:  [-1322.91133028]
# Episode:  224 Time:  200 Reward:  [-1195.37251506]
# Episode:  225 Time:  200 Reward:  [-1252.90619958]
# Episode:  226 Time:  200 Reward:  [-1334.87455057]
# Episode:  227 Time:  200 Reward:  [-1260.83077788]
# Episode:  228 Time:  200 Reward:  [-1156.4218768]
# Episode:  229 Time:  200 Reward:  [-1200.02679147]
# Episode:  230 Time:  200 Reward:  [-1175.01788614]
# Episode:  231 Time:  200 Reward:  [-1198.29427155]
# Episode:  232 Time:  200 Reward:  [-867.63223606]
# Episode:  233 Time:  200 Reward:  [-1142.83776179]
# Episode:  234 Time:  200 Reward:  [-1141.69095341]
# Episode:  235 Time:  200 Reward:  [-1214.81007873]
# Episode:  236 Time:  200 Reward:  [-1297.36779108]
# Episode:  237 Time:  200 Reward:  [-1323.17073961]
# Episode:  238 Time:  200 Reward:  [-1241.1403243]
# Episode:  239 Time:  200 Reward:  [-1121.58101242]
# Episode:  240 Time:  200 Reward:  [-1119.38989077]
# Episode:  241 Time:  200 Reward:  [-1036.47770565]
# Episode:  242 Time:  200 Reward:  [-1125.95456454]
# Episode:  243 Time:  200 Reward:  [-1180.34655389]
# Episode:  244 Time:  200 Reward:  [-1258.69760804]
# Episode:  245 Time:  200 Reward:  [-1137.79754721]
# Episode:  246 Time:  200 Reward:  [-1320.84454277]
# Episode:  247 Time:  200 Reward:  [-1083.85568642]
# Episode:  248 Time:  200 Reward:  [-1228.93967082]
# Episode:  249 Time:  200 Reward:  [-1301.47688777]
# Episode:  250 Time:  200 Reward:  [-1050.12748156]
# Episode:  251 Time:  200 Reward:  [-1140.29003038]
# Episode:  252 Time:  200 Reward:  [-1288.77260778]
# Episode:  253 Time:  200 Reward:  [-1176.782885]
# Episode:  254 Time:  200 Reward:  [-1054.77926759]
# Episode:  255 Time:  200 Reward:  [-1166.31299009]
# Episode:  256 Time:  200 Reward:  [-1266.48433091]
# Episode:  257 Time:  200 Reward:  [-1200.09583418]
# Episode:  258 Time:  200 Reward:  [-1264.91101689]
# Episode:  259 Time:  200 Reward:  [-1170.03485042]
# Episode:  260 Time:  200 Reward:  [-1111.99974132]
# Episode:  261 Time:  200 Reward:  [-1356.00393816]
# Episode:  262 Time:  200 Reward:  [-1199.71523834]
# Episode:  263 Time:  200 Reward:  [-1163.34577574]
# Episode:  264 Time:  200 Reward:  [-1039.4527809]
# Episode:  265 Time:  200 Reward:  [-1133.16175937]
# Episode:  266 Time:  200 Reward:  [-1052.54377673]
# Episode:  267 Time:  200 Reward:  [-1046.44309804]
# Episode:  268 Time:  200 Reward:  [-1137.7706328]
# Episode:  269 Time:  200 Reward:  [-1041.12272547]
# Episode:  270 Time:  200 Reward:  [-1063.36661829]
# Episode:  271 Time:  200 Reward:  [-1183.61971423]
# Episode:  272 Time:  200 Reward:  [-1157.72629516]
# Episode:  273 Time:  200 Reward:  [-1087.39787326]
# Episode:  274 Time:  200 Reward:  [-1230.72310392]
# Episode:  275 Time:  200 Reward:  [-871.12361893]
# Episode:  276 Time:  200 Reward:  [-1149.63770305]
# Episode:  277 Time:  200 Reward:  [-1020.84208462]
# Episode:  278 Time:  200 Reward:  [-1165.8512004]
# Episode:  279 Time:  200 Reward:  [-1127.10113821]
# Episode:  280 Time:  200 Reward:  [-1050.36205342]
# Episode:  281 Time:  200 Reward:  [-1156.31581495]
# Episode:  282 Time:  200 Reward:  [-1175.76718393]
# Episode:  283 Time:  200 Reward:  [-1050.47456453]
# Episode:  284 Time:  200 Reward:  [-1049.09518116]
# Episode:  285 Time:  200 Reward:  [-1050.2274969]
# Episode:  286 Time:  200 Reward:  [-988.47512623]
# Episode:  287 Time:  200 Reward:  [-1087.01259664]
# Episode:  288 Time:  200 Reward:  [-890.6021379]
# Episode:  289 Time:  200 Reward:  [-1161.66926263]
# Episode:  290 Time:  200 Reward:  [-937.94472261]
# Episode:  291 Time:  200 Reward:  [-1057.6323884]
# Episode:  292 Time:  200 Reward:  [-1107.71318476]
# Episode:  293 Time:  200 Reward:  [-937.83673051]
# Episode:  294 Time:  200 Reward:  [-932.5202306]
# Episode:  295 Time:  200 Reward:  [-1171.91031823]
# Episode:  296 Time:  200 Reward:  [-1140.80805346]
# Episode:  297 Time:  200 Reward:  [-1186.02042829]
# Episode:  298 Time:  200 Reward:  [-1036.1371041]
# Episode:  299 Time:  200 Reward:  [-1068.39024885]
# Episode:  300 Time:  200 Reward:  [-1166.4668918]
# Episode:  301 Time:  200 Reward:  [-1016.51591869]
# Episode:  302 Time:  200 Reward:  [-1008.78106655]
# Episode:  303 Time:  200 Reward:  [-1170.10385958]
# Episode:  304 Time:  200 Reward:  [-901.26319337]
# Episode:  305 Time:  200 Reward:  [-1146.15353548]
# Episode:  306 Time:  200 Reward:  [-1144.04525304]
# Episode:  307 Time:  200 Reward:  [-925.11794891]
# Episode:  308 Time:  200 Reward:  [-638.35603563]
# Episode:  309 Time:  200 Reward:  [-1157.00383188]
# Episode:  310 Time:  200 Reward:  [-1085.25794023]
# Episode:  311 Time:  200 Reward:  [-1056.58794902]
# Episode:  312 Time:  200 Reward:  [-750.47784252]
# Episode:  313 Time:  200 Reward:  [-1014.52176633]
# Episode:  314 Time:  200 Reward:  [-1136.30728284]
# Episode:  315 Time:  200 Reward:  [-1040.19221341]
# Episode:  316 Time:  200 Reward:  [-907.32867657]
# Episode:  317 Time:  200 Reward:  [-1118.60723164]
# Episode:  318 Time:  200 Reward:  [-1038.80898572]
# Episode:  319 Time:  200 Reward:  [-999.59975251]
# Episode:  320 Time:  200 Reward:  [-1259.12672288]
# Episode:  321 Time:  200 Reward:  [-1133.09807437]
# Episode:  322 Time:  200 Reward:  [-1042.15168902]
# Episode:  323 Time:  200 Reward:  [-1127.93256336]
# Episode:  324 Time:  200 Reward:  [-912.43261934]
# Episode:  325 Time:  200 Reward:  [-880.81772046]
# Episode:  326 Time:  200 Reward:  [-904.27330099]
# Episode:  327 Time:  200 Reward:  [-1005.38289738]
# Episode:  328 Time:  200 Reward:  [-1118.94209948]
# Episode:  329 Time:  200 Reward:  [-1023.44820396]
# Episode:  330 Time:  200 Reward:  [-853.06134321]
# Episode:  331 Time:  200 Reward:  [-917.75030942]
# Episode:  332 Time:  200 Reward:  [-911.33588929]
# Episode:  333 Time:  200 Reward:  [-1022.65622687]
# Episode:  334 Time:  200 Reward:  [-1165.92776086]
# Episode:  335 Time:  200 Reward:  [-885.31560278]
# Episode:  336 Time:  200 Reward:  [-1224.78277611]
# Episode:  337 Time:  200 Reward:  [-777.94618603]
# Episode:  338 Time:  200 Reward:  [-1076.98128828]
# Episode:  339 Time:  200 Reward:  [-999.14966412]
# Episode:  340 Time:  200 Reward:  [-1264.98920722]
# Episode:  341 Time:  200 Reward:  [-901.5325421]
# Episode:  342 Time:  200 Reward:  [-1043.1033138]
# Episode:  343 Time:  200 Reward:  [-1078.39722888]
# Episode:  344 Time:  200 Reward:  [-1008.07676175]
# Episode:  345 Time:  200 Reward:  [-1210.35006758]
# Episode:  346 Time:  200 Reward:  [-1040.48799729]
# Episode:  347 Time:  200 Reward:  [-1144.36654636]
# Episode:  348 Time:  200 Reward:  [-1049.97140141]
# Episode:  349 Time:  200 Reward:  [-1162.90490833]
# Episode:  350 Time:  200 Reward:  [-1091.25926954]
# Episode:  351 Time:  200 Reward:  [-1182.64689285]
# Episode:  352 Time:  200 Reward:  [-1167.20546342]
# Episode:  353 Time:  200 Reward:  [-1176.93418309]
# Episode:  354 Time:  200 Reward:  [-1178.74016985]
# Episode:  355 Time:  200 Reward:  [-1178.31854095]
# Episode:  356 Time:  200 Reward:  [-1181.71759744]
# Episode:  357 Time:  200 Reward:  [-1169.33874726]
# Episode:  358 Time:  200 Reward:  [-1169.35531358]
# Episode:  359 Time:  200 Reward:  [-1293.94522276]
# Episode:  360 Time:  200 Reward:  [-1276.46869845]
# Episode:  361 Time:  200 Reward:  [-1226.54556334]
# Episode:  362 Time:  200 Reward:  [-1222.89340684]
# Episode:  363 Time:  200 Reward:  [-1061.46750387]
# Episode:  364 Time:  200 Reward:  [-1032.57313179]
# Episode:  365 Time:  200 Reward:  [-1288.7111487]
# Episode:  366 Time:  200 Reward:  [-1032.93038672]
# Episode:  367 Time:  200 Reward:  [-1329.80221733]
# Episode:  368 Time:  200 Reward:  [-878.86738382]
# Episode:  369 Time:  200 Reward:  [-1302.64422268]
# Episode:  370 Time:  200 Reward:  [-1335.98132214]
# Episode:  371 Time:  200 Reward:  [-1208.33557997]
# Episode:  372 Time:  200 Reward:  [-911.9701156]
# Episode:  373 Time:  200 Reward:  [-1028.27904213]
# Episode:  374 Time:  200 Reward:  [-1251.25223483]
# Episode:  375 Time:  200 Reward:  [-932.03757616]
# Episode:  376 Time:  200 Reward:  [-1183.56810469]
# Episode:  377 Time:  200 Reward:  [-1068.7347408]
# Episode:  378 Time:  200 Reward:  [-910.91690099]
# Episode:  379 Time:  200 Reward:  [-1095.86163711]
# Episode:  380 Time:  200 Reward:  [-1083.16412458]
# Episode:  381 Time:  200 Reward:  [-1051.82433723]
# Episode:  382 Time:  200 Reward:  [-873.19565794]
# Episode:  383 Time:  200 Reward:  [-1125.47177799]
# Episode:  384 Time:  200 Reward:  [-1091.32928938]
# Episode:  385 Time:  200 Reward:  [-1064.11813962]
# Episode:  386 Time:  200 Reward:  [-1143.79529157]
# Episode:  387 Time:  200 Reward:  [-931.11313925]
# Episode:  388 Time:  200 Reward:  [-1033.58842847]
# Episode:  389 Time:  200 Reward:  [-1043.53867243]
# Episode:  390 Time:  200 Reward:  [-1161.35913487]
# Episode:  391 Time:  200 Reward:  [-1067.66528656]
# Episode:  392 Time:  200 Reward:  [-1186.76513792]
# Episode:  393 Time:  200 Reward:  [-1077.91843267]
# Episode:  394 Time:  200 Reward:  [-1114.42146268]
# Episode:  395 Time:  200 Reward:  [-929.32196256]
# Episode:  396 Time:  200 Reward:  [-1018.8694793]
# Episode:  397 Time:  200 Reward:  [-1141.54326241]
# Episode:  398 Time:  200 Reward:  [-1056.03755772]
# Episode:  399 Time:  200 Reward:  [-1065.75934626]
# Episode:  400 Time:  200 Reward:  [-920.7607684]
# Episode:  401 Time:  200 Reward:  [-1155.65109181]
# Episode:  402 Time:  200 Reward:  [-1081.10198566]
# Episode:  403 Time:  200 Reward:  [-1080.98028041]
# Episode:  404 Time:  200 Reward:  [-1047.412595]
# Episode:  405 Time:  200 Reward:  [-1040.7323897]
# Episode:  406 Time:  200 Reward:  [-1116.12061174]
# Episode:  407 Time:  200 Reward:  [-1131.9731657]
# Episode:  408 Time:  200 Reward:  [-963.37558562]
# Episode:  409 Time:  200 Reward:  [-1156.51939874]
# Episode:  410 Time:  200 Reward:  [-942.77557931]
# Episode:  411 Time:  200 Reward:  [-1060.69324955]
# Episode:  412 Time:  200 Reward:  [-831.05818159]
# Episode:  413 Time:  200 Reward:  [-1134.41703785]
# Episode:  414 Time:  200 Reward:  [-959.22073281]
# Episode:  415 Time:  200 Reward:  [-1108.24966959]
# Episode:  416 Time:  200 Reward:  [-1142.2026537]
# Episode:  417 Time:  200 Reward:  [-1049.72285512]
# Episode:  418 Time:  200 Reward:  [-1019.33252496]
# Episode:  419 Time:  200 Reward:  [-754.73524894]
# Episode:  420 Time:  200 Reward:  [-770.4695103]
# Episode:  421 Time:  200 Reward:  [-1116.29212241]
# Episode:  422 Time:  200 Reward:  [-999.17361953]
# Episode:  423 Time:  200 Reward:  [-997.04534475]
# Episode:  424 Time:  200 Reward:  [-977.60051919]
# Episode:  425 Time:  200 Reward:  [-1039.640577]
# Episode:  426 Time:  200 Reward:  [-1059.05843829]
# Episode:  427 Time:  200 Reward:  [-1047.97103211]
# Episode:  428 Time:  200 Reward:  [-1050.11497878]
# Episode:  429 Time:  200 Reward:  [-1147.80320409]
# Episode:  430 Time:  200 Reward:  [-954.63915384]
# Episode:  431 Time:  200 Reward:  [-1010.99674269]
# Episode:  432 Time:  200 Reward:  [-1073.15212554]
# Episode:  433 Time:  200 Reward:  [-1146.90457142]
# Episode:  434 Time:  200 Reward:  [-1133.34479598]
# Episode:  435 Time:  200 Reward:  [-1086.87837745]
# Episode:  436 Time:  200 Reward:  [-1049.4100338]
# Episode:  437 Time:  200 Reward:  [-1128.39982504]
# Episode:  438 Time:  200 Reward:  [-1040.81260411]
# Episode:  439 Time:  200 Reward:  [-794.84610017]
# Episode:  440 Time:  200 Reward:  [-795.38099833]
# Episode:  441 Time:  200 Reward:  [-946.13531123]
# Episode:  442 Time:  200 Reward:  [-925.77764364]
# Episode:  443 Time:  200 Reward:  [-1123.02914786]
# Episode:  444 Time:  200 Reward:  [-1062.07825158]
# Episode:  445 Time:  200 Reward:  [-1186.00244325]
# Episode:  446 Time:  200 Reward:  [-1187.27209945]
# Episode:  447 Time:  200 Reward:  [-1177.36829573]
# Episode:  448 Time:  200 Reward:  [-1158.32442538]
# Episode:  449 Time:  200 Reward:  [-981.91540121]
# Episode:  450 Time:  200 Reward:  [-887.25659582]
# Episode:  451 Time:  200 Reward:  [-1117.19968741]
# Episode:  452 Time:  200 Reward:  [-1031.23393205]
# Episode:  453 Time:  200 Reward:  [-1176.98250178]
# Episode:  454 Time:  200 Reward:  [-1024.25065608]
# Episode:  455 Time:  200 Reward:  [-1027.53769939]
# Episode:  456 Time:  200 Reward:  [-1188.83160024]
# Episode:  457 Time:  200 Reward:  [-1040.690042]
# Episode:  458 Time:  200 Reward:  [-1165.2296363]
# Episode:  459 Time:  200 Reward:  [-958.7929725]
# Episode:  460 Time:  200 Reward:  [-1062.95923168]
# Episode:  461 Time:  200 Reward:  [-1035.46341853]
# Episode:  462 Time:  200 Reward:  [-870.30487524]
# Episode:  463 Time:  200 Reward:  [-1019.96258809]
# Episode:  464 Time:  200 Reward:  [-777.80971989]
# Episode:  465 Time:  200 Reward:  [-1158.41038148]
# Episode:  466 Time:  200 Reward:  [-990.99818269]
# Episode:  467 Time:  200 Reward:  [-1127.04190775]
# Episode:  468 Time:  200 Reward:  [-1053.33575768]
# Episode:  469 Time:  200 Reward:  [-1047.99289612]
# Episode:  470 Time:  200 Reward:  [-914.25186142]
# Episode:  471 Time:  200 Reward:  [-1061.53169537]
# Episode:  472 Time:  200 Reward:  [-1036.79837429]
# Episode:  473 Time:  200 Reward:  [-1010.55576185]
# Episode:  474 Time:  200 Reward:  [-961.99543935]
# Episode:  475 Time:  200 Reward:  [-1091.90845591]
# Episode:  476 Time:  200 Reward:  [-1048.83040567]
# Episode:  477 Time:  200 Reward:  [-1064.2544771]
# Episode:  478 Time:  200 Reward:  [-1061.66915559]
# Episode:  479 Time:  200 Reward:  [-1094.9400188]
# Episode:  480 Time:  200 Reward:  [-1179.8235776]
# Episode:  481 Time:  200 Reward:  [-818.74976263]
# Episode:  482 Time:  200 Reward:  [-1026.3476572]
# Episode:  483 Time:  200 Reward:  [-927.36286627]
# Episode:  484 Time:  200 Reward:  [-1146.24184196]
# Episode:  485 Time:  200 Reward:  [-916.73731581]
# Episode:  486 Time:  200 Reward:  [-1074.59176485]
# Episode:  487 Time:  200 Reward:  [-1143.39395688]
# Episode:  488 Time:  200 Reward:  [-1115.1215764]
# Episode:  489 Time:  200 Reward:  [-1121.16957333]
# Episode:  490 Time:  200 Reward:  [-992.36884423]
# Episode:  491 Time:  200 Reward:  [-625.04051605]
# Episode:  492 Time:  200 Reward:  [-812.32276318]
# Episode:  493 Time:  200 Reward:  [-944.0363749]
# Episode:  494 Time:  200 Reward:  [-764.21480409]
# Episode:  495 Time:  200 Reward:  [-1037.0890746]
# Episode:  496 Time:  200 Reward:  [-1064.38678916]
# Episode:  497 Time:  200 Reward:  [-1115.03013665]
# Episode:  498 Time:  200 Reward:  [-1033.2038473]
# Episode:  499 Time:  200 Reward:  [-1026.35775088]
# Episode:  500 Time:  200 Reward:  [-1111.95759245]
# Episode:  501 Time:  200 Reward:  [-1017.8791036]
# Episode:  502 Time:  200 Reward:  [-910.2720541]
# Episode:  503 Time:  200 Reward:  [-1036.53992746]
# Episode:  504 Time:  200 Reward:  [-899.25305289]
# Episode:  505 Time:  200 Reward:  [-1070.69410821]
# Episode:  506 Time:  200 Reward:  [-1000.13911382]
# Episode:  507 Time:  200 Reward:  [-1032.83802488]
# Episode:  508 Time:  200 Reward:  [-910.56265301]
# Episode:  509 Time:  200 Reward:  [-1036.22964408]
# Episode:  510 Time:  200 Reward:  [-907.70003569]
# Episode:  511 Time:  200 Reward:  [-748.37764187]
# Episode:  512 Time:  200 Reward:  [-895.55637476]
# Episode:  513 Time:  200 Reward:  [-780.11789083]
# Episode:  514 Time:  200 Reward:  [-1083.68901643]
# Episode:  515 Time:  200 Reward:  [-639.20621579]
# Episode:  516 Time:  200 Reward:  [-919.33480113]
# Episode:  517 Time:  200 Reward:  [-947.51412828]
# Episode:  518 Time:  200 Reward:  [-1096.02979177]
# Episode:  519 Time:  200 Reward:  [-753.39551973]
# Episode:  520 Time:  200 Reward:  [-921.89277412]
# Episode:  521 Time:  200 Reward:  [-975.63818022]
# Episode:  522 Time:  200 Reward:  [-1037.95565292]
# Episode:  523 Time:  200 Reward:  [-1023.84855109]
# Episode:  524 Time:  200 Reward:  [-998.52687952]
# Episode:  525 Time:  200 Reward:  [-1049.24858211]
# Episode:  526 Time:  200 Reward:  [-811.97728857]
# Episode:  527 Time:  200 Reward:  [-723.43911043]
# Episode:  528 Time:  200 Reward:  [-923.77290528]
# Episode:  529 Time:  200 Reward:  [-884.25714976]
# Episode:  530 Time:  200 Reward:  [-758.72862881]
# Episode:  531 Time:  200 Reward:  [-756.70575843]
# Episode:  532 Time:  200 Reward:  [-749.57691563]
# Episode:  533 Time:  200 Reward:  [-761.87868778]
# Episode:  534 Time:  200 Reward:  [-1034.42224039]
# Episode:  535 Time:  200 Reward:  [-770.50339253]
# Episode:  536 Time:  200 Reward:  [-895.82525684]
# Episode:  537 Time:  200 Reward:  [-1041.08635444]
# Episode:  538 Time:  200 Reward:  [-1104.09674765]
# Episode:  539 Time:  200 Reward:  [-1015.9816498]
# Episode:  540 Time:  200 Reward:  [-1082.65779084]
# Episode:  541 Time:  200 Reward:  [-1286.43291065]
# Episode:  542 Time:  200 Reward:  [-1199.42640047]
# Episode:  543 Time:  200 Reward:  [-1176.3381705]
# Episode:  544 Time:  200 Reward:  [-1162.78980203]
# Episode:  545 Time:  200 Reward:  [-1181.60823855]
# Episode:  546 Time:  200 Reward:  [-1051.92499409]
# Episode:  547 Time:  200 Reward:  [-1045.95660221]
# Episode:  548 Time:  200 Reward:  [-987.0127]
# Episode:  549 Time:  200 Reward:  [-1008.68683198]
# Episode:  550 Time:  200 Reward:  [-750.52698038]
# Episode:  551 Time:  200 Reward:  [-897.21037245]
# Episode:  552 Time:  200 Reward:  [-983.56332478]
# Episode:  553 Time:  200 Reward:  [-1055.37541083]
# Episode:  554 Time:  200 Reward:  [-988.84259593]
# Episode:  555 Time:  200 Reward:  [-802.19043434]
# Episode:  556 Time:  200 Reward:  [-693.21237611]
# Episode:  557 Time:  200 Reward:  [-919.70347157]
# Episode:  558 Time:  200 Reward:  [-800.19759539]
# Episode:  559 Time:  200 Reward:  [-901.07535192]
# Episode:  560 Time:  200 Reward:  [-904.01592044]
# Episode:  561 Time:  200 Reward:  [-1113.93508744]
# Episode:  562 Time:  200 Reward:  [-1057.27595385]
# Episode:  563 Time:  200 Reward:  [-1027.92525254]
# Episode:  564 Time:  200 Reward:  [-1007.04566177]
# Episode:  565 Time:  200 Reward:  [-903.97519062]
# Episode:  566 Time:  200 Reward:  [-833.91584147]
# Episode:  567 Time:  200 Reward:  [-907.58877531]
# Episode:  568 Time:  200 Reward:  [-1021.05804301]
# Episode:  569 Time:  200 Reward:  [-1045.32244671]
# Episode:  570 Time:  200 Reward:  [-1044.33352533]
# Episode:  571 Time:  200 Reward:  [-740.06405829]
# Episode:  572 Time:  200 Reward:  [-892.8137301]
# Episode:  573 Time:  200 Reward:  [-855.11982971]
# Episode:  574 Time:  200 Reward:  [-818.22023391]
# Episode:  575 Time:  200 Reward:  [-893.2253413]
# Episode:  576 Time:  200 Reward:  [-821.24506736]
# Episode:  577 Time:  200 Reward:  [-648.0928691]
# Episode:  578 Time:  200 Reward:  [-637.24613616]
# Episode:  579 Time:  200 Reward:  [-383.70555489]
# Episode:  580 Time:  200 Reward:  [-633.44685851]
# Episode:  581 Time:  200 Reward:  [-508.22481031]
# Episode:  582 Time:  200 Reward:  [-776.74085301]
# Episode:  583 Time:  200 Reward:  [-777.14578245]
# Episode:  584 Time:  200 Reward:  [-632.39249383]
# Episode:  585 Time:  200 Reward:  [-904.74128917]
# Episode:  586 Time:  200 Reward:  [-852.66182025]
# Episode:  587 Time:  200 Reward:  [-985.57725505]
# Episode:  588 Time:  200 Reward:  [-1042.83491658]
# Episode:  589 Time:  200 Reward:  [-1051.58061824]
# Episode:  590 Time:  200 Reward:  [-1028.18515551]
# Episode:  591 Time:  200 Reward:  [-974.5196845]
# Episode:  592 Time:  200 Reward:  [-928.94964699]
# Episode:  593 Time:  200 Reward:  [-924.17378845]
# Episode:  594 Time:  200 Reward:  [-994.85883897]
# Episode:  595 Time:  200 Reward:  [-914.70708046]
# Episode:  596 Time:  200 Reward:  [-991.73386217]
# Episode:  597 Time:  200 Reward:  [-1044.28135215]
# Episode:  598 Time:  200 Reward:  [-1032.35624696]
# Episode:  599 Time:  200 Reward:  [-717.34597412]
# Episode:  600 Time:  200 Reward:  [-782.44911392]
# Episode:  601 Time:  200 Reward:  [-1134.96332063]
# Episode:  602 Time:  200 Reward:  [-1044.71905012]
# Episode:  603 Time:  200 Reward:  [-878.51450875]
# Episode:  604 Time:  200 Reward:  [-1058.31766758]
# Episode:  605 Time:  200 Reward:  [-1046.39268777]
# Episode:  606 Time:  200 Reward:  [-1059.55715444]
# Episode:  607 Time:  200 Reward:  [-1169.46865135]
# Episode:  608 Time:  200 Reward:  [-1186.92753118]
# Episode:  609 Time:  200 Reward:  [-1202.02554658]
# Episode:  610 Time:  200 Reward:  [-1076.19249423]
# Episode:  611 Time:  200 Reward:  [-912.56370813]
# Episode:  612 Time:  200 Reward:  [-708.15545709]
# Episode:  613 Time:  200 Reward:  [-1188.58192542]
# Episode:  614 Time:  200 Reward:  [-1195.07773001]
# Episode:  615 Time:  200 Reward:  [-1115.29386386]
# Episode:  616 Time:  200 Reward:  [-1178.69368625]
# Episode:  617 Time:  200 Reward:  [-1070.76141458]
# Episode:  618 Time:  200 Reward:  [-1163.60970873]
# Episode:  619 Time:  200 Reward:  [-1232.88342168]
# Episode:  620 Time:  200 Reward:  [-1182.68257552]
# Episode:  621 Time:  200 Reward:  [-1194.27848638]
# Episode:  622 Time:  200 Reward:  [-1145.17921261]
# Episode:  623 Time:  200 Reward:  [-1089.48854258]
# Episode:  624 Time:  200 Reward:  [-1087.22158158]
# Episode:  625 Time:  200 Reward:  [-1061.86342154]
# Episode:  626 Time:  200 Reward:  [-1040.28593163]
# Episode:  627 Time:  200 Reward:  [-1047.65878191]
# Episode:  628 Time:  200 Reward:  [-1055.9812275]
# Episode:  629 Time:  200 Reward:  [-1036.08501797]
# Episode:  630 Time:  200 Reward:  [-1243.3420163]
# Episode:  631 Time:  200 Reward:  [-1203.15772814]
# Episode:  632 Time:  200 Reward:  [-1163.38453835]
# Episode:  633 Time:  200 Reward:  [-1186.93534003]
# Episode:  634 Time:  200 Reward:  [-903.73812083]
# Episode:  635 Time:  200 Reward:  [-1066.7243119]
# Episode:  636 Time:  200 Reward:  [-1041.48121919]
# Episode:  637 Time:  200 Reward:  [-903.50112211]
# Episode:  638 Time:  200 Reward:  [-914.57446523]
# Episode:  639 Time:  200 Reward:  [-1056.90504118]
# Episode:  640 Time:  200 Reward:  [-1014.56574753]
# Episode:  641 Time:  200 Reward:  [-1020.8810304]
# Episode:  642 Time:  200 Reward:  [-1090.44071475]
# Episode:  643 Time:  200 Reward:  [-1051.77661637]
# Episode:  644 Time:  200 Reward:  [-1112.98376533]
# Episode:  645 Time:  200 Reward:  [-1021.05715102]
# Episode:  646 Time:  200 Reward:  [-1174.45829236]
# Episode:  647 Time:  200 Reward:  [-1179.48257037]
# Episode:  648 Time:  200 Reward:  [-1090.33033373]
# Episode:  649 Time:  200 Reward:  [-1153.80027277]
# Episode:  650 Time:  200 Reward:  [-1046.88558003]
# Episode:  651 Time:  200 Reward:  [-1064.16598178]
# Episode:  652 Time:  200 Reward:  [-1087.3071722]
# Episode:  653 Time:  200 Reward:  [-1068.00544798]
# Episode:  654 Time:  200 Reward:  [-1055.23993486]
# Episode:  655 Time:  200 Reward:  [-801.83802035]
# Episode:  656 Time:  200 Reward:  [-897.96072394]
# Episode:  657 Time:  200 Reward:  [-921.96316022]
# Episode:  658 Time:  200 Reward:  [-1029.76512845]
# Episode:  659 Time:  200 Reward:  [-1121.72196691]
# Episode:  660 Time:  200 Reward:  [-1124.69206727]
# Episode:  661 Time:  200 Reward:  [-1072.00709181]
# Episode:  662 Time:  200 Reward:  [-1031.13123674]
# Episode:  663 Time:  200 Reward:  [-886.36088516]
# Episode:  664 Time:  200 Reward:  [-1026.48182117]
# Episode:  665 Time:  200 Reward:  [-1001.68409073]
# Episode:  666 Time:  200 Reward:  [-1048.26153732]
# Episode:  667 Time:  200 Reward:  [-1059.28932795]
# Episode:  668 Time:  200 Reward:  [-928.9920556]
# Episode:  669 Time:  200 Reward:  [-1182.02391516]
# Episode:  670 Time:  200 Reward:  [-791.44943651]
# Episode:  671 Time:  200 Reward:  [-1275.60791091]
# Episode:  672 Time:  200 Reward:  [-1069.97609469]
# Episode:  673 Time:  200 Reward:  [-1204.690775]
# Episode:  674 Time:  200 Reward:  [-1002.78379438]
# Episode:  675 Time:  200 Reward:  [-1163.95444744]
# Episode:  676 Time:  200 Reward:  [-779.25788134]
# Episode:  677 Time:  200 Reward:  [-1020.5575602]
# Episode:  678 Time:  200 Reward:  [-1198.69112866]
# Episode:  679 Time:  200 Reward:  [-508.60044712]
# Episode:  680 Time:  200 Reward:  [-577.90914691]
# Episode:  681 Time:  200 Reward:  [-1149.59365703]
# Episode:  682 Time:  200 Reward:  [-1042.77102693]
# Episode:  683 Time:  200 Reward:  [-796.52578164]
# Episode:  684 Time:  200 Reward:  [-1204.14269173]
# Episode:  685 Time:  200 Reward:  [-782.77539977]
# Episode:  686 Time:  200 Reward:  [-1104.86773534]
# Episode:  687 Time:  200 Reward:  [-1169.17193496]
# Episode:  688 Time:  200 Reward:  [-1062.1959612]
# Episode:  689 Time:  200 Reward:  [-1016.01571687]
# Episode:  690 Time:  200 Reward:  [-1180.00382782]
# Episode:  691 Time:  200 Reward:  [-1044.89500606]
# Episode:  692 Time:  200 Reward:  [-1045.20102979]
# Episode:  693 Time:  200 Reward:  [-1113.07151321]
# Episode:  694 Time:  200 Reward:  [-1046.25381892]
# Episode:  695 Time:  200 Reward:  [-1010.23199744]
# Episode:  696 Time:  200 Reward:  [-920.38609947]
# Episode:  697 Time:  200 Reward:  [-770.35808913]
# Episode:  698 Time:  200 Reward:  [-1065.01130545]
# Episode:  699 Time:  200 Reward:  [-720.83627584]
# Episode:  700 Time:  200 Reward:  [-1043.50210979]
# Episode:  701 Time:  200 Reward:  [-1145.35489872]
# Episode:  702 Time:  200 Reward:  [-1029.28136086]
# Episode:  703 Time:  200 Reward:  [-1036.28054477]
# Episode:  704 Time:  200 Reward:  [-920.87254508]
# Episode:  705 Time:  200 Reward:  [-907.57095423]
# Episode:  706 Time:  200 Reward:  [-752.41835597]
# Episode:  707 Time:  200 Reward:  [-777.39792285]
# Episode:  708 Time:  200 Reward:  [-938.08610685]
# Episode:  709 Time:  200 Reward:  [-887.24415557]
# Episode:  710 Time:  200 Reward:  [-889.86919581]
# Episode:  711 Time:  200 Reward:  [-1048.98909501]
# Episode:  712 Time:  200 Reward:  [-630.7974663]
# Episode:  713 Time:  200 Reward:  [-1020.70177372]
# Episode:  714 Time:  200 Reward:  [-476.43093444]
# Episode:  715 Time:  200 Reward:  [-614.75011979]
# Episode:  716 Time:  200 Reward:  [-508.31838062]
# Episode:  717 Time:  200 Reward:  [-637.28162161]
# Episode:  718 Time:  200 Reward:  [-557.4968409]
# Episode:  719 Time:  200 Reward:  [-630.04146875]
# Episode:  720 Time:  200 Reward:  [-925.10520456]
# Episode:  721 Time:  200 Reward:  [-627.14581428]
# Episode:  722 Time:  200 Reward:  [-806.44646535]
# Episode:  723 Time:  200 Reward:  [-796.1407271]
# Episode:  724 Time:  200 Reward:  [-848.2839144]
# Episode:  725 Time:  200 Reward:  [-1017.40795073]
# Episode:  726 Time:  200 Reward:  [-732.16214859]
# Episode:  727 Time:  200 Reward:  [-971.60707255]
# Episode:  728 Time:  200 Reward:  [-640.70453044]
# Episode:  729 Time:  200 Reward:  [-784.53293676]
# Episode:  730 Time:  200 Reward:  [-652.00619293]
# Episode:  731 Time:  200 Reward:  [-637.85674357]
# Episode:  732 Time:  200 Reward:  [-779.72862305]
# Episode:  733 Time:  200 Reward:  [-635.26919095]
# Episode:  734 Time:  200 Reward:  [-638.64049895]
# Episode:  735 Time:  200 Reward:  [-425.32622358]
# Episode:  736 Time:  200 Reward:  [-517.29292042]
# Episode:  737 Time:  200 Reward:  [-883.81121629]
# Episode:  738 Time:  200 Reward:  [-651.51551771]
# Episode:  739 Time:  200 Reward:  [-396.50835509]
# Episode:  740 Time:  200 Reward:  [-894.89023946]
# Episode:  741 Time:  200 Reward:  [-656.1706981]
# Episode:  742 Time:  200 Reward:  [-474.75815379]
# Episode:  743 Time:  200 Reward:  [-915.12634322]
# Episode:  744 Time:  200 Reward:  [-820.02600262]
# Episode:  745 Time:  200 Reward:  [-1025.67235361]
# Episode:  746 Time:  200 Reward:  [-671.27641258]
# Episode:  747 Time:  200 Reward:  [-1063.19975733]
# Episode:  748 Time:  200 Reward:  [-918.46462858]
# Episode:  749 Time:  200 Reward:  [-1036.03704593]
# Episode:  750 Time:  200 Reward:  [-1129.20395716]
# Episode:  751 Time:  200 Reward:  [-657.2301888]
# Episode:  752 Time:  200 Reward:  [-461.36224929]
# Episode:  753 Time:  200 Reward:  [-1056.34174513]
# Episode:  754 Time:  200 Reward:  [-920.6021294]
# Episode:  755 Time:  200 Reward:  [-1049.04140079]
# Episode:  756 Time:  200 Reward:  [-1132.36610776]
# Episode:  757 Time:  200 Reward:  [-733.72322471]
# Episode:  758 Time:  200 Reward:  [-553.95844478]
# Episode:  759 Time:  200 Reward:  [-761.30058793]
# Episode:  760 Time:  200 Reward:  [-1109.58143382]
# Episode:  761 Time:  200 Reward:  [-890.95138851]
# Episode:  762 Time:  200 Reward:  [-892.40847844]
# Episode:  763 Time:  200 Reward:  [-532.82989194]
# Episode:  764 Time:  200 Reward:  [-887.54102815]
# Episode:  765 Time:  200 Reward:  [-861.81096022]
# Episode:  766 Time:  200 Reward:  [-1023.43951574]
# Episode:  767 Time:  200 Reward:  [-529.8047157]
# Episode:  768 Time:  200 Reward:  [-760.17116713]
# Episode:  769 Time:  200 Reward:  [-946.08936427]
# Episode:  770 Time:  200 Reward:  [-880.79408637]
# Episode:  771 Time:  200 Reward:  [-1050.80882849]
# Episode:  772 Time:  200 Reward:  [-1027.69746654]
# Episode:  773 Time:  200 Reward:  [-680.04762911]
# Episode:  774 Time:  200 Reward:  [-988.33145963]
# Episode:  775 Time:  200 Reward:  [-376.25920981]
# Episode:  776 Time:  200 Reward:  [-722.19509738]
# Episode:  777 Time:  200 Reward:  [-506.51930805]
# Episode:  778 Time:  200 Reward:  [-1058.69292325]
# Episode:  779 Time:  200 Reward:  [-777.6710248]
# Episode:  780 Time:  200 Reward:  [-1112.25439521]
# Episode:  781 Time:  200 Reward:  [-919.80111892]
# Episode:  782 Time:  200 Reward:  [-779.3760877]
# Episode:  783 Time:  200 Reward:  [-927.9864003]
# Episode:  784 Time:  200 Reward:  [-908.95016047]
# Episode:  785 Time:  200 Reward:  [-901.6027104]
# Episode:  786 Time:  200 Reward:  [-769.44953375]
# Episode:  787 Time:  200 Reward:  [-1013.7661194]
# Episode:  788 Time:  200 Reward:  [-702.23522235]
# Episode:  789 Time:  200 Reward:  [-711.29791503]
# Episode:  790 Time:  200 Reward:  [-519.68381594]
# Episode:  791 Time:  200 Reward:  [-523.88154903]
# Episode:  792 Time:  200 Reward:  [-131.66893667]
# Episode:  793 Time:  200 Reward:  [-250.43584972]
# Episode:  794 Time:  200 Reward:  [-875.99459316]
# Episode:  795 Time:  200 Reward:  [-132.02536713]
# Episode:  796 Time:  200 Reward:  [-900.74721618]
# Episode:  797 Time:  200 Reward:  [-1162.34377354]
# Episode:  798 Time:  200 Reward:  [-1002.76987634]
# Episode:  799 Time:  200 Reward:  [-1057.12343739]
# Episode:  800 Time:  200 Reward:  [-1031.09885278]
# Episode:  801 Time:  200 Reward:  [-1043.92788981]
# Episode:  802 Time:  200 Reward:  [-810.19758213]
# Episode:  803 Time:  200 Reward:  [-905.11229524]
# Episode:  804 Time:  200 Reward:  [-915.85914607]
# Episode:  805 Time:  200 Reward:  [-766.5889114]
# Episode:  806 Time:  200 Reward:  [-900.77578919]
# Episode:  807 Time:  200 Reward:  [-1031.67693061]
# Episode:  808 Time:  200 Reward:  [-650.34637277]
# Episode:  809 Time:  200 Reward:  [-935.19094526]
# Episode:  810 Time:  200 Reward:  [-777.40941097]
# Episode:  811 Time:  200 Reward:  [-897.51760443]
# Episode:  812 Time:  200 Reward:  [-519.38632746]
# Episode:  813 Time:  200 Reward:  [-252.38492426]
# Episode:  814 Time:  200 Reward:  [-250.57141907]
# Episode:  815 Time:  200 Reward:  [-375.73459765]
# Episode:  816 Time:  200 Reward:  [-1058.8193782]
# Episode:  817 Time:  200 Reward:  [-611.80538487]
# Episode:  818 Time:  200 Reward:  [-257.9543532]
# Episode:  819 Time:  200 Reward:  [-888.35905951]
# Episode:  820 Time:  200 Reward:  [-530.11840973]
# Episode:  821 Time:  200 Reward:  [-260.52940474]
# Episode:  822 Time:  200 Reward:  [-734.5672726]
# Episode:  823 Time:  200 Reward:  [-756.87347574]
# Episode:  824 Time:  200 Reward:  [-898.32290106]
# Episode:  825 Time:  200 Reward:  [-525.86706919]
# Episode:  826 Time:  200 Reward:  [-1014.41291238]
# Episode:  827 Time:  200 Reward:  [-936.11133063]
# Episode:  828 Time:  200 Reward:  [-260.38175648]
# Episode:  829 Time:  200 Reward:  [-785.73064635]
# Episode:  830 Time:  200 Reward:  [-650.59585173]
# Episode:  831 Time:  200 Reward:  [-687.93528539]
# Episode:  832 Time:  200 Reward:  [-619.50635034]
# Episode:  833 Time:  200 Reward:  [-506.65873238]
# Episode:  834 Time:  200 Reward:  [-623.74450653]
# Episode:  835 Time:  200 Reward:  [-925.51734079]
# Episode:  836 Time:  200 Reward:  [-497.53879126]
# Episode:  837 Time:  200 Reward:  [-381.53021502]
# Episode:  838 Time:  200 Reward:  [-636.43524086]
# Episode:  839 Time:  200 Reward:  [-374.50536025]
# Episode:  840 Time:  200 Reward:  [-332.82909989]
# Episode:  841 Time:  200 Reward:  [-254.59876326]
# Episode:  842 Time:  200 Reward:  [-377.20500969]
# Episode:  843 Time:  200 Reward:  [-904.27338858]
# Episode:  844 Time:  200 Reward:  [-915.87008571]
# Episode:  845 Time:  200 Reward:  [-908.56585049]
# Episode:  846 Time:  200 Reward:  [-381.89234523]
# Episode:  847 Time:  200 Reward:  [-402.66554867]
# Episode:  848 Time:  200 Reward:  [-376.22383493]
# Episode:  849 Time:  200 Reward:  [-132.40260168]
# Episode:  850 Time:  200 Reward:  [-913.29422093]
# Episode:  851 Time:  200 Reward:  [-921.67778298]
# Episode:  852 Time:  200 Reward:  [-124.52820935]
# Episode:  853 Time:  200 Reward:  [-253.87024711]
# Episode:  854 Time:  200 Reward:  [-413.79601948]
# Episode:  855 Time:  200 Reward:  [-638.27126967]
# Episode:  856 Time:  200 Reward:  [-884.18774515]
# Episode:  857 Time:  200 Reward:  [-429.51490876]
# Episode:  858 Time:  200 Reward:  [-619.69712343]
# Episode:  859 Time:  200 Reward:  [-783.77470715]
# Episode:  860 Time:  200 Reward:  [-608.39620467]
# Episode:  861 Time:  200 Reward:  [-501.78950941]
# Episode:  862 Time:  200 Reward:  [-256.40553504]
# Episode:  863 Time:  200 Reward:  [-534.51099508]
# Episode:  864 Time:  200 Reward:  [-250.21502587]
# Episode:  865 Time:  200 Reward:  [-390.81198046]
# Episode:  866 Time:  200 Reward:  [-373.64931873]
# Episode:  867 Time:  200 Reward:  [-130.51001305]
# Episode:  868 Time:  200 Reward:  [-373.78174683]
# Episode:  869 Time:  200 Reward:  [-371.37645152]
# Episode:  870 Time:  200 Reward:  [-247.39352013]
# Episode:  871 Time:  200 Reward:  [-254.36593846]
# Episode:  872 Time:  200 Reward:  [-128.17971188]
# Episode:  873 Time:  200 Reward:  [-126.99237486]
# Episode:  874 Time:  200 Reward:  [-903.14083371]
# Episode:  875 Time:  200 Reward:  [-122.48954684]
# Episode:  876 Time:  200 Reward:  [-387.99038651]
# Episode:  877 Time:  200 Reward:  [-369.34378999]
# Episode:  878 Time:  200 Reward:  [-123.60222196]
# Episode:  879 Time:  200 Reward:  [-0.75421771]
# Episode:  880 Time:  200 Reward:  [-630.12296169]
# Episode:  881 Time:  200 Reward:  [-256.5409605]
# Episode:  882 Time:  200 Reward:  [-249.45224676]
# Episode:  883 Time:  200 Reward:  [-133.38932342]
# Episode:  884 Time:  200 Reward:  [-1089.68742926]
# Episode:  885 Time:  200 Reward:  [-251.67517543]
# Episode:  886 Time:  200 Reward:  [-251.13803285]
# Episode:  887 Time:  200 Reward:  [-1045.78893409]
# Episode:  888 Time:  200 Reward:  [-128.70528608]
# Episode:  889 Time:  200 Reward:  [-508.71486265]
# Episode:  890 Time:  200 Reward:  [-773.88253711]
# Episode:  891 Time:  200 Reward:  [-899.87626089]
# Episode:  892 Time:  200 Reward:  [-261.79026168]
# Episode:  893 Time:  200 Reward:  [-924.78886579]
# Episode:  894 Time:  200 Reward:  [-1042.62783789]
# Episode:  895 Time:  200 Reward:  [-794.92795169]
# Episode:  896 Time:  200 Reward:  [-241.39935871]
# Episode:  897 Time:  200 Reward:  [-482.55316022]
# Episode:  898 Time:  200 Reward:  [-0.94068667]
# Episode:  899 Time:  200 Reward:  [-912.6833116]
# Episode:  900 Time:  200 Reward:  [-397.51198844]
# Episode:  901 Time:  200 Reward:  [-129.79628776]
# Episode:  902 Time:  200 Reward:  [-250.9850388]
# Episode:  903 Time:  200 Reward:  [-520.80891603]
# Episode:  904 Time:  200 Reward:  [-135.05754458]
# Episode:  905 Time:  200 Reward:  [-128.98369578]
# Episode:  906 Time:  200 Reward:  [-2.2716412]
# Episode:  907 Time:  200 Reward:  [-962.87578871]
# Episode:  908 Time:  200 Reward:  [-926.32565509]
# Episode:  909 Time:  200 Reward:  [-628.81605107]
# Episode:  910 Time:  200 Reward:  [-581.45709508]
# Episode:  911 Time:  200 Reward:  [-785.11229319]
# Episode:  912 Time:  200 Reward:  [-2.80428773]
# Episode:  913 Time:  200 Reward:  [-131.11752883]
# Episode:  914 Time:  200 Reward:  [-2.37342301]
# Episode:  915 Time:  200 Reward:  [-1.24176064]
# Episode:  916 Time:  200 Reward:  [-557.65560554]
# Episode:  917 Time:  200 Reward:  [-568.63902199]
# Episode:  918 Time:  200 Reward:  [-128.38279496]
# Episode:  919 Time:  200 Reward:  [-393.41805975]
# Episode:  920 Time:  200 Reward:  [-2.29571706]
# Episode:  921 Time:  200 Reward:  [-528.10430557]
# Episode:  922 Time:  200 Reward:  [-128.94401676]
# Episode:  923 Time:  200 Reward:  [-537.28116802]
# Episode:  924 Time:  200 Reward:  [-501.38336888]
# Episode:  925 Time:  200 Reward:  [-252.43313663]
# Episode:  926 Time:  200 Reward:  [-372.88970127]
# Episode:  927 Time:  200 Reward:  [-127.90881621]
# Episode:  928 Time:  200 Reward:  [-365.21335042]
# Episode:  929 Time:  200 Reward:  [-379.28590902]
# Episode:  930 Time:  200 Reward:  [-129.45173529]
# Episode:  931 Time:  200 Reward:  [-247.1910524]
# Episode:  932 Time:  200 Reward:  [-130.70958796]
# Episode:  933 Time:  200 Reward:  [-0.48229225]
# Episode:  934 Time:  200 Reward:  [-256.15483148]
# Episode:  935 Time:  200 Reward:  [-538.71234752]
# Episode:  936 Time:  200 Reward:  [-130.76157504]
# Episode:  937 Time:  200 Reward:  [-594.24938981]
# Episode:  938 Time:  200 Reward:  [-385.34320912]
# Episode:  939 Time:  200 Reward:  [-126.00891973]
# Episode:  940 Time:  200 Reward:  [-125.08774278]
# Episode:  941 Time:  200 Reward:  [-0.33347683]
# Episode:  942 Time:  200 Reward:  [-252.96923281]
# Episode:  943 Time:  200 Reward:  [-126.30735136]
# Episode:  944 Time:  200 Reward:  [-124.71354932]
# Episode:  945 Time:  200 Reward:  [-381.56580968]
# Episode:  946 Time:  200 Reward:  [-128.61915286]
# Episode:  947 Time:  200 Reward:  [-390.66886315]
# Episode:  948 Time:  200 Reward:  [-123.14180683]
# Episode:  949 Time:  200 Reward:  [-382.93152846]
# Episode:  950 Time:  200 Reward:  [-123.50610623]
# Episode:  951 Time:  200 Reward:  [-947.01533651]
# Episode:  952 Time:  200 Reward:  [-808.28820503]
# Episode:  953 Time:  200 Reward:  [-581.7614619]
# Episode:  954 Time:  200 Reward:  [-244.62410784]
# Episode:  955 Time:  200 Reward:  [-1.79567844]
# Episode:  956 Time:  200 Reward:  [-742.02577116]
# Episode:  957 Time:  200 Reward:  [-131.21895175]
# Episode:  958 Time:  200 Reward:  [-389.34340671]
# Episode:  959 Time:  200 Reward:  [-129.95636938]
# Episode:  960 Time:  200 Reward:  [-387.46813674]
# Episode:  961 Time:  200 Reward:  [-370.58805144]
# Episode:  962 Time:  200 Reward:  [-891.3966995]
# Episode:  963 Time:  200 Reward:  [-945.58739244]
# Episode:  964 Time:  200 Reward:  [-919.46524896]
# Episode:  965 Time:  200 Reward:  [-0.80517814]
# Episode:  966 Time:  200 Reward:  [-255.23329211]
# Episode:  967 Time:  200 Reward:  [-380.19251689]
# Episode:  968 Time:  200 Reward:  [-656.87397058]
# Episode:  969 Time:  200 Reward:  [-131.01918331]
# Episode:  970 Time:  200 Reward:  [-1015.90562645]
# Episode:  971 Time:  200 Reward:  [-1024.42382241]
# Episode:  972 Time:  200 Reward:  [-130.1918171]
# Episode:  973 Time:  200 Reward:  [-374.77853517]
# Episode:  974 Time:  200 Reward:  [-253.13858705]
# Episode:  975 Time:  200 Reward:  [-123.94429807]
# Episode:  976 Time:  200 Reward:  [-468.0942174]
# Episode:  977 Time:  200 Reward:  [-129.24963251]
# Episode:  978 Time:  200 Reward:  [-258.08330786]
# Episode:  979 Time:  200 Reward:  [-632.74709203]
# Episode:  980 Time:  200 Reward:  [-378.96407212]
# Episode:  981 Time:  200 Reward:  [-382.89080067]
# Episode:  982 Time:  200 Reward:  [-382.22091041]
# Episode:  983 Time:  200 Reward:  [-127.861268]
# Episode:  984 Time:  200 Reward:  [-395.27187199]
# Episode:  985 Time:  200 Reward:  [-494.48120903]
# Episode:  986 Time:  200 Reward:  [-248.17879537]
# Episode:  987 Time:  200 Reward:  [-260.04690359]
# Episode:  988 Time:  200 Reward:  [-255.09408664]
# Episode:  989 Time:  200 Reward:  [-368.64493484]
# Episode:  990 Time:  200 Reward:  [-131.58150463]
# Episode:  991 Time:  200 Reward:  [-399.81106104]
# Episode:  992 Time:  200 Reward:  [-507.38304753]
# Episode:  993 Time:  200 Reward:  [-254.77237729]
# Episode:  994 Time:  200 Reward:  [-1.82124624]
# Episode:  995 Time:  200 Reward:  [-129.63001866]
# Episode:  996 Time:  200 Reward:  [-129.73471669]
# Episode:  997 Time:  200 Reward:  [-257.0453586]
# Episode:  998 Time:  200 Reward:  [-2.94326973]
# Episode:  999 Time:  200 Reward:  [-395.65732893]
# Episode:  1000 Time:  200 Reward:  [-404.66138091]
# [array([-1648.13779536]), array([-1519.48939481]), array([-1589.48216227]), array([-1549.03520038]), array([-1873.91475581]), array([-1617.34467058]), array([-1596.34314807]), array([-1365.54698268]), array([-1483.80796709]), array([-1721.05981758]), array([-1585.06375174]), array([-1671.26561792]), array([-1863.13341938]), array([-1542.68948629]), array([-1472.26928957]), array([-1807.10864818]), array([-1842.49134359]), array([-1498.26253422]), array([-1762.76040365]), array([-1508.32204446]), array([-1849.61095933]), array([-1842.17844064]), array([-1700.42240537]), array([-1428.59307781]), array([-1537.9898877]), array([-1764.65248614]), array([-1483.71873047]), array([-1825.52094976]), array([-1614.84856444]), array([-1426.59377188]), array([-1484.92023246]), array([-1032.35989055]), array([-1076.70999739]), array([-1726.23225539]), array([-1857.16781786]), array([-1479.93567527]), array([-1718.82555134]), array([-1809.74038807]), array([-1418.75008205]), array([-1489.95542544]), array([-1212.33117843]), array([-1647.8874401]), array([-1587.91499497]), array([-1576.33451143]), array([-1203.78280008]), array([-1623.51719937]), array([-1435.10629884]), array([-1809.05154856]), array([-1740.3518218]), array([-1871.78464131]), array([-1569.66111346]), array([-1414.18223825]), array([-1863.44987615]), array([-1666.88176154]), array([-1595.63501996]), array([-1482.41171588]), array([-1504.77476315]), array([-1325.15395475]), array([-1643.7919439]), array([-1637.85676953]), array([-965.73359514]), array([-1570.43962595]), array([-1316.88713202]), array([-1363.59895958]), array([-1476.21023707]), array([-1240.98962729]), array([-1228.63675927]), array([-1333.61520932]), array([-1254.32902403]), array([-1277.06383105]), array([-1400.26093962]), array([-1171.29777725]), array([-1503.3681323]), array([-1225.58157314]), array([-1186.88091782]), array([-1119.66183537]), array([-1295.89843708]), array([-1297.30141647]), array([-1474.00605023]), array([-1562.26607784]), array([-1170.67205583]), array([-1314.75716102]), array([-1267.37510358]), array([-1170.3637939]), array([-1107.40998094]), array([-1204.69505675]), array([-1309.33360034]), array([-1335.70651036]), array([-1376.27463675]), array([-1478.42337487]), array([-1403.19222402]), array([-1326.72492064]), array([-1249.68876664]), array([-1353.36410889]), array([-1452.45652754]), array([-1375.24451911]), array([-1450.79545514]), array([-1347.2645774]), array([-1309.57448306]), array([-1435.7741967]), array([-1317.50435691]), array([-1515.37441185]), array([-905.28415516]), array([-1302.95875882]), array([-1377.2181165]), array([-1298.90682132]), array([-1523.93142764]), array([-1276.94783148]), array([-1354.30520085]), array([-1146.10257175]), array([-1385.43729298]), array([-1393.35490989]), array([-1372.67133997]), array([-1276.48573081]), array([-1305.71004691]), array([-1249.49882832]), array([-1340.32385869]), array([-1382.17273393]), array([-1341.37923413]), array([-1325.72797303]), array([-1286.38598187]), array([-1349.09313379]), array([-1225.23980893]), array([-1295.67491249]), array([-1374.6868665]), array([-1285.70503222]), array([-1313.59855476]), array([-1470.34710976]), array([-1239.00431449]), array([-1443.63604563]), array([-1371.31242102]), array([-1310.51473095]), array([-1441.67319273]), array([-1315.55949888]), array([-1360.35905026]), array([-1310.42527751]), array([-1231.64465802]), array([-1456.16307755]), array([-1291.93983021]), array([-1298.30178205]), array([-1317.76030462]), array([-1340.507836]), array([-1324.54880009]), array([-1330.78913269]), array([-1342.00446559]), array([-1339.38642297]), array([-1412.43369792]), array([-1366.73211073]), array([-1424.27254435]), array([-1210.14621852]), array([-1370.77983579]), array([-1249.39373394]), array([-1341.41946803]), array([-1324.56441866]), array([-1348.41476166]), array([-1281.50465363]), array([-1307.26453873]), array([-1345.88419043]), array([-1314.55705176]), array([-1371.55162915]), array([-1323. ...

# %%
# A2C main

import gym


def main():

    env_name = 'Pendulum-v0'
    env = gym.make(env_name)
    agent = A2Cagent(env)

    agent.actor.load_weights('./save_weights/')
    agent.critic.load_weights('./save_weights/')

    time = 0
    state = env.reset()

    while True:
        
        action = agent.actor.predict(state)
        state, reward, done, _ = env.step(action)
        time += 1

        print('Time: ', time, 'Reward: ', reward)

        if done:
            break

    env.close()

if __name__=="__main__":
    main()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 3)]          0
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           256         input_3[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32)           2080        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 16)           528         dense_10[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            17          dense_11[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1)            17          dense_11[0][0]
# ==================================================================================================
# Total params: 2,898
# Trainable params: 2,898
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                256
# _________________________________________________________________
# dense_15 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_16 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 2,881
# Trainable params: 2,881
# Non-trainable params: 0
# _________________________________________________________________
# Time:  1 Reward:  -1.704195913541715
# Time:  2 Reward:  -1.7135528525125114
# Time:  3 Reward:  -1.8206692700590774
# Time:  4 Reward:  -2.0310228114386137
# Time:  5 Reward:  -2.3567470613464208
# Time:  6 Reward:  -2.819007705774263
# Time:  7 Reward:  -3.4464939331143674
# Time:  8 Reward:  -4.281408202445188
# Time:  9 Reward:  -5.394404335667594
# Time:  10 Reward:  -6.874867682281402
# Time:  11 Reward:  -8.769324993374315
# Time:  12 Reward:  -11.021728703074448
# Time:  13 Reward:  -13.503228934183799
# Time:  14 Reward:  -12.55775361454452
# Time:  15 Reward:  -10.850166685783345
# Time:  16 Reward:  -9.097296787553839
# Time:  17 Reward:  -7.386054083018145
# Time:  18 Reward:  -5.7863655784020835
# Time:  19 Reward:  -4.30067422846418
# Time:  20 Reward:  -3.031013415485188
# Time:  21 Reward:  -2.0621992470366597
# Time:  22 Reward:  -1.3938800726150222
# Time:  23 Reward:  -0.9589510394590827
# Time:  24 Reward:  -0.6937010548041428
# Time:  25 Reward:  -0.5378718240282476
# Time:  26 Reward:  -0.4506259566944084
# Time:  27 Reward:  -0.4012838690275803
# Time:  28 Reward:  -0.37567519458015847
# Time:  29 Reward:  -0.36815722583062177
# Time:  30 Reward:  -0.3765320677596371
# Time:  31 Reward:  -0.4004470713788518
# Time:  32 Reward:  -0.4413803655555842
# Time:  33 Reward:  -0.5026025888909044
# Time:  34 Reward:  -0.5889862253013409
# Time:  35 Reward:  -0.7075714768510791
# Time:  36 Reward:  -0.8681105189500163
# Time:  37 Reward:  -1.0837496748300763
# Time:  38 Reward:  -1.371298240205391
# Time:  39 Reward:  -1.7518376711310197
# Time:  40 Reward:  -2.2508426386389586
# Time:  41 Reward:  -2.8965400441242815
# Time:  42 Reward:  -3.7190247267725227
# Time:  43 Reward:  -4.748215986241109
# Time:  44 Reward:  -6.010940865050016
# Time:  45 Reward:  -7.559277054246651
# Time:  46 Reward:  -9.477941924753782
# Time:  47 Reward:  -11.771306065156242
# Time:  48 Reward:  -14.04178920928574
# Time:  49 Reward:  -12.354352592623494
# Time:  50 Reward:  -10.58142523795861
# Time:  51 Reward:  -8.791529302753975
# Time:  52 Reward:  -7.082720486051303
# Time:  53 Reward:  -5.5482630124033685
# Time:  54 Reward:  -4.2304702738046664
# Time:  55 Reward:  -3.117961333406115
# Time:  56 Reward:  -2.1918748421033203
# Time:  57 Reward:  -1.4691241506727075
# Time:  58 Reward:  -0.9553586269388324
# Time:  59 Reward:  -0.6059255741254193
# Time:  60 Reward:  -0.3773589668299061
# Time:  61 Reward:  -0.23244184028977385
# Time:  62 Reward:  -0.1500597662362904
# Time:  63 Reward:  -0.10665512820008022
# Time:  64 Reward:  -0.08178969073476816
# Time:  65 Reward:  -0.06553166328377938
# Time:  66 Reward:  -0.05368246292875853
# Time:  67 Reward:  -0.04451680911579994
# Time:  68 Reward:  -0.03713115470816012
# Time:  69 Reward:  -0.031015656017750443
# Time:  70 Reward:  -0.025869269215981233
# Time:  71 Reward:  -0.02150273668032219
# Time:  72 Reward:  -0.017788282258373592
# Time:  73 Reward:  -0.014632562583908463
# Time:  74 Reward:  -0.011962063268338952
# Time:  75 Reward:  -0.009715380829267707
# Time:  76 Reward:  -0.007839232591833861
# Time:  77 Reward:  -0.006285376763682503
# Time:  78 Reward:  -0.005000203001202962
# Time:  79 Reward:  -0.003954019548135101
# Time:  80 Reward:  -0.0031192508951037356
# Time:  81 Reward:  -0.002465139391985671
# Time:  82 Reward:  -0.0019665149002206788
# Time:  83 Reward:  -0.0015998217565134766
# Time:  84 Reward:  -0.0013438625511424625
# Time:  85 Reward:  -0.001179994989318458
# Time:  86 Reward:  -0.0010920747634886902
# Time:  87 Reward:  -0.001066242471619691
# Time:  88 Reward:  -0.0010906930066170398
# Time:  89 Reward:  -0.001155414166045875
# Time:  90 Reward:  -0.0012519606958293506
# Time:  91 Reward:  -0.0013732323719757456
# Time:  92 Reward:  -0.0015132870363101752
# Time:  93 Reward:  -0.0016671706337736776
# Time:  94 Reward:  -0.0018307710518169812
# Time:  95 Reward:  -0.0020006944578537474
# Time:  96 Reward:  -0.002174153115926197
# Time:  97 Reward:  -0.0023488720826540382
# Time:  98 Reward:  -0.0025230103321133724
# Time:  99 Reward:  -0.0026950963933468166
# Time:  100 Reward:  -0.002863962465669965
# Time:  101 Reward:  -0.0030286985384887347
# Time:  102 Reward:  -0.0031886131277309533
# Time:  103 Reward:  -0.0033431918405418025
# Time:  104 Reward:  -0.003492067282603416
# Time:  105 Reward:  -0.003634999211767661
# Time:  106 Reward:  -0.003771846357465287
# Time:  107 Reward:  -0.003902549755139106
# Time:  108 Reward:  -0.004027119021496435
# Time:  109 Reward:  -0.0041456164619631045
# Time:  110 Reward:  -0.004258146266994655
# Time:  111 Reward:  -0.004364849980099323
# Time:  112 Reward:  -0.004465888934964723
# Time:  113 Reward:  -0.004561448512589267
# Time:  114 Reward:  -0.004651726060491189
# Time:  115 Reward:  -0.004736927805196674
# Time:  116 Reward:  -0.004817268468898423
# Time:  117 Reward:  -0.004892960003293105
# Time:  118 Reward:  -0.00496422054604918
# Time:  119 Reward:  -0.005031262352348606
# Time:  120 Reward:  -0.005094297839053518
# Time:  121 Reward:  -0.005153529834789168
# Time:  122 Reward:  -0.005209160532555366
# Time:  123 Reward:  -0.005261383152015481
# Time:  124 Reward:  -0.005310385694046586
# Time:  125 Reward:  -0.00535634786097385
# Time:  126 Reward:  -0.005399441227515901
# Time:  127 Reward:  -0.005439830481441295
# Time:  128 Reward:  -0.005477675410900812
# Time:  129 Reward:  -0.005513124972279511
# Time:  130 Reward:  -0.005546321898881766
# Time:  131 Reward:  -0.0055774022726359255
# Time:  132 Reward:  -0.005606492070415827
# Time:  133 Reward:  -0.005633714989566664
# Time:  134 Reward:  -0.005659186361466601
# Time:  135 Reward:  -0.0056830119683868845
# Time:  136 Reward:  -0.005705294889091125
# Time:  137 Reward:  -0.005726133669080756
# Time:  138 Reward:  -0.005745616845015542
# Time:  139 Reward:  -0.005763832270897511
# Time:  140 Reward:  -0.005780859106266674
# Time:  141 Reward:  -0.005796772432750666
# Time:  142 Reward:  -0.005811644980547213
# Time:  143 Reward:  -0.005825541674332943
# Time:  144 Reward:  -0.0058385267648402685
# Time:  145 Reward:  -0.005850658343082645
# Time:  146 Reward:  -0.005861992335642307
# Time:  147 Reward:  -0.00587257970640376
# Time:  148 Reward:  -0.005882467778197226
# Time:  149 Reward:  -0.005891705031435952
# Time:  150 Reward:  -0.005900331938429397
# Time:  151 Reward:  -0.0059083884392773945
# Time:  152 Reward:  -0.005915912332622977
# Time:  153 Reward:  -0.005922937012979056
# Time:  154 Reward:  -0.005929497300747452
# Time:  155 Reward:  -0.005935622081397598
# Time:  156 Reward:  -0.005941340598807655
# Time:  157 Reward:  -0.005946680054506602
# Time:  158 Reward:  -0.005951665035475299
# Time:  159 Reward:  -0.005956318683251693
# Time:  160 Reward:  -0.005960662671308933
# Time:  161 Reward:  -0.005964717772339837
# Time:  162 Reward:  -0.005968504288069094
# Time:  163 Reward:  -0.00597203911040488
# Time:  164 Reward:  -0.005975337374066726
# Time:  165 Reward:  -0.0059784163614608875
# Time:  166 Reward:  -0.005981291050362132
# Time:  167 Reward:  -0.005983972861930313
# Time:  168 Reward:  -0.005986477318485402
# Time:  169 Reward:  -0.005988814447439534
# Time:  170 Reward:  -0.005990995740046275
# Time:  171 Reward:  -0.005993032173431552
# Time:  172 Reward:  -0.005994933062241862
# Time:  173 Reward:  -0.005996705921284011
# Time:  174 Reward:  -0.005998362004637521
# Time:  175 Reward:  -0.005999906836335273
# Time:  176 Reward:  -0.006001348753193621
# Time:  177 Reward:  -0.006002695268380684
# Time:  178 Reward:  -0.006003950619214524
# Time:  179 Reward:  -0.006005123021210763
# Time:  180 Reward:  -0.006006217119732868
# Time:  181 Reward:  -0.006007237195228601
# Time:  182 Reward:  -0.006008190021532835
# Time:  183 Reward:  -0.0060090789249701414
# Time:  184 Reward:  -0.006009908693478147
# Time:  185 Reward:  -0.0060106829713901
# Time:  186 Reward:  -0.006011406070463223
# Time:  187 Reward:  -0.006012080816603471
# Time:  188 Reward:  -0.006012710105786647
# Time:  189 Reward:  -0.00601329696764323
# Time:  190 Reward:  -0.006013844710095014
# Time:  191 Reward:  -0.006014356117907116
# Time:  192 Reward:  -0.006014832753870263
# Time:  193 Reward:  -0.0060152789898385624
# Time:  194 Reward:  -0.006015693425048194
# Time:  195 Reward:  -0.0060160827982094975
# Time:  196 Reward:  -0.006016444324817732
# Time:  197 Reward:  -0.00601678303524126
# Time:  198 Reward:  -0.006017098329008963
# Time:  199 Reward:  -0.006017393946863925
# Time:  200 Reward:  -0.0060176686055996515
